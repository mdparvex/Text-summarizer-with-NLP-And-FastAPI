# %%
# !pip install attention
# !pip install lxml
# Out:
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from attention) (1.26.4)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.11/dist-packages (from attention) (2.18.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->attention) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->attention) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->attention) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->attention) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->attention) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->attention) (2.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1->attention) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1->attention) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1->attention) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.1.3)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->attention) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->attention) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->attention) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.1->attention) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.1->attention) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.1->attention) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1->attention) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.1->attention) (0.1.2)
# Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Installing collected packages: attention
# Successfully installed attention-5.0.0
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (5.4.0)

# %%
#from attention import AttentionLayer
#from tensorflow.keras.layers import Attention
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
# from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# 2025-09-08 04:42:10.337092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757306530.719827      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757306530.825692      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
data=pd.read_csv("/kaggle/input/review/dataset/Reviews.csv",nrows=100000)

# %%
data.drop_duplicates(subset=['Text'],inplace=True)  #dropping duplicates
data.dropna(axis=0,inplace=True)   #dropping na

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
data['Text'][:10]
# Out:
# 0    I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1             Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2    This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3    If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4                                                               Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# 5    I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there wa...
# 6    This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, ...
# 7                                                               This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 8                                                                        Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 9                                                                  This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# Name: Text, dtype: object

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t))

# %%
data['Summary'][:10]
# Out:
# 0                            Good Quality Dog Food
# 1                                Not as Advertised
# 2                            "Delight" says it all
# 3                                   Cough Medicine
# 4                                      Great taffy
# 5                                       Nice Taffy
# 6    Great!  Just as good as the expensive brands!
# 7                           Wonderful, tasty taffy
# 8                                       Yay Barley
# 9                                 Healthy Dog Food
# Name: Summary, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:
            newString=newString+i+' '
    return newString

#Call the above function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# Summary: _START_ good quality dog food  _END_
#
#
# Review: product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# Summary: _START_ not as advertised  _END_
#
#
# Review: confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# Summary: _START_ delight says it all  _END_
#
#
# Review: looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# Summary: _START_ cough medicine  _END_
#
#
# Review: great taffy great price wide assortment yummy taffy delivery quick taffy lover deal
# Summary: _START_ great taffy  _END_

# %%
import matplotlib.pyplot as plt
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
max_len_text=80
max_len_summary=10

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr)
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post')
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr)
y_val   =   y_tokenizer.texts_to_sequences(y_val)

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
from keras.layers import Layer
from keras import backend as K
import tensorflow as tf

class AttentionLayer(Layer):
  def __init__(self, **kwargs):
      super(AttentionLayer, self).__init__(**kwargs)

  def build(self, input_shape):
    assert isinstance(input_shape, list)

    self.W_a = self.add_weight(name='W_a',
                                shape=(input_shape[0][2], input_shape[0][2]),
                                initializer='uniform',
                                trainable=True)
    self.U_a = self.add_weight(name='U_a',
                                shape=(input_shape[1][2], input_shape[0][2]),
                                initializer='uniform',
                                trainable=True)
    self.V_a = self.add_weight(name='V_a',
                                shape=(input_shape[0][2], 1),
                                initializer='uniform',
                                trainable=True)
    super(AttentionLayer, self).build(input_shape)

  def call(self, inputs):
    encoder_outputs, decoder_outputs = inputs  # encoder: [B, Tx, H], decoder: [B, Ty, H]

    # Linear projections
    W_a_dot_enc = tf.tensordot(encoder_outputs, self.W_a, axes=[[2], [0]])  # [B, Tx, H]
    U_a_dot_dec = tf.tensordot(decoder_outputs, self.U_a, axes=[[2], [0]])  # [B, Ty, H]

    # Broadcast add: expand dimensions
    WU_add = tf.nn.tanh(tf.expand_dims(U_a_dot_dec, 2) + tf.expand_dims(W_a_dot_enc, 1))  # [B, Ty, Tx, H]

    # Score → [B, Ty, Tx]
    score = tf.squeeze(tf.tensordot(WU_add, self.V_a, axes=[[3], [0]]), axis=-1)

    # Attention weights
    attention_weights = tf.nn.softmax(score, axis=-1)  # [B, Ty, Tx]

    # Context vector: [B, Ty, H]
    context_vector = tf.matmul(attention_weights, encoder_outputs)

    return context_vector, attention_weights



  def compute_output_shape(self, input_shape):
    return input_shape[1], input_shape[0]

# %%
from keras import backend as K
K.clear_session()
latent_dim = 500

# Encoder
encoder_inputs = Input(shape=(max_len_text,))
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs)

#LSTM 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#LSTM 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#LSTM 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder.
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention output and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 80)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 80, 500)   │ 25,886,500 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 80, 500), │  2,002,000 │ embedding[0][0]   │
# │                     │ (None, 500),      │            │                   │
# │                     │ (None, 500)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 80, 500), │  2,002,000 │ lstm[0][0]        │
# │                     │ (None, 500),      │            │                   │
# │                     │ (None, 500)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 500) │  7,072,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 80, 500), │  2,002,000 │ lstm_1[0][0]      │
# │                     │ (None, 500),      │            │                   │
# │                     │ (None, 500)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │  2,002,000 │ embedding_1[0][0… │
# │                     │ 500), (None,      │            │ lstm_2[0][1],     │
# │                     │ 500), (None,      │            │ lstm_2[0][2]      │
# │                     │ 500)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer     │ [(None, None,     │    500,500 │ lstm_2[0][0],     │
# │ (AttentionLayer)    │ 500), (None, 80,  │            │ lstm_3[0][0]      │
# │                     │ 500)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_layer        │ (None, None,      │          0 │ lstm_3[0][0],     │
# │ (Concatenate)       │ 1000)             │            │ attention_layer[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, None,      │ 14,158,144 │ concat_layer[0][… │
# │ (TimeDistributed)   │ 14144)            │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 55,625,144 (212.19 MB)
#  Trainable params: 55,625,144 (212.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history = model.fit(
    [x_tr, y_tr[:, :-1]],      # input seq + decoder input (no <end>)
    y_tr[:, 1:],               # decoder target (no <start>)
    epochs=50,
    callbacks=[es],
    batch_size=512,
    validation_data=(
        [x_val, y_val[:, :-1]],
        y_val[:, 1:]
    )
)
# Out:
# Epoch 1/50
# I0000 00:00:1757306656.587518     115 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 133s 791ms/step - loss: 4.3128 - val_loss: 2.9746
# Epoch 2/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 129s 830ms/step - loss: 3.0765 - val_loss: 2.9525
# Epoch 3/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 3.0404 - val_loss: 2.8987
# Epoch 4/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.9672 - val_loss: 2.8396
# Epoch 5/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.9147 - val_loss: 2.8077
# Epoch 6/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.8752 - val_loss: 2.7717
# Epoch 7/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.8327 - val_loss: 2.7083
# Epoch 8/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.7807 - val_loss: 2.6653
# Epoch 9/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.7260 - val_loss: 2.6326
# Epoch 10/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.6951 - val_loss: 2.6099
# Epoch 11/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.6640 - val_loss: 2.5909
# Epoch 12/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.6407 - val_loss: 2.5497
# Epoch 13/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.6005 - val_loss: 2.5378
# Epoch 14/50
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 130s 835ms/step - loss: 2.5750 - val_loss: 2.6116
# Epoch 14: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])
#save this model here to use in the application

# %%
# Save encoder and decoder
encoder_model.save("encoder_model.h5")
decoder_model.save("decoder_model.h5")

# Also save tokenizer mappings (you’ll need them for preprocessing/postprocessing)
import pickle

with open("target_word_index.pkl", "wb") as f:
    pickle.dump(target_word_index, f)

with open("reverse_target_word_index.pkl", "wb") as f:
    pickle.dump(reverse_target_word_index, f)

with open("x_tokenizer.pkl", "wb") as f:
    pickle.dump(x_tokenizer, f)

# %%
def decode_sequence(input_seq):
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    target_seq = np.zeros((1,1))
    target_seq[0,0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index.get(sampled_token_index, '')

        if sampled_token != '' and sampled_token != 'end':
            decoded_sentence += ' ' + sampled_token

        if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
            stop_condition = True

        target_seq = np.zeros((1,1))
        target_seq[0,0] = sampled_token_index

        e_h, e_c = h, c

    return decoded_sentence.strip()

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(len(x_val)):
  print("Review:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Review: loves things though think taste nasty hahaha actually learned chew gums matter picky pull eat know carbs best thing least know organic cheese puff buying amazon saved money stores three dollars
# Original summary: this is my daughter favorite snack
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: yes block awesome bought many times processed cheese real deal aged sharp cheddar made found last holiday season love nippy mild deliciously great large serving block uncut pounds nutrition inch cube calories fat grams sodium cholesterol carbs zero trans fats saturated fat grams protein grams excellent chop appetizers party trays due extra large block size cut sandwhich size slices huge thick block perfect uncut unprocessed nice product deli direct compliments cheese spreads wraps rolled sandwiches ten stars consistent customer months
# Original summary: say cheese
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great for the price
#
#
# Review: favorite white tea delicate light full spectrum flavor really hard find quality white tea leaves huge bag found dust fannings love white peony tea
# Original summary: wonderful white tea
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: disagree another reviewer find gritty always natural without added sugar also find sweet nice overpowering taste maple great snack rice cakes
# Original summary: yummy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: really enjoy yogi licorice tea really wondering mint licorice would work finally ordered pleasantly surprised delicious replacing straight licorice licorice mint future nice curl
# Original summary: wish would tried this sooner
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tea
#
#
# Review: cannot say good kobe steak tastes like package received spoiled greatly dismayed handling expensive delivery try kobe fine restaurant instead home grill
# Original summary: disappointed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great product
#
#
# Review: earl grey flavor fragrance intense tea brands bland love tea
# Original summary: like no other earl grey
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tea
#
#
# Review: order chocolate winter didnt trouble time ordered summer orders arrived melted worth dont know product maybe use baking
# Original summary: bad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: bigelow earl grey tea cups quite good made keurig elite gourmet single cup home brewing system small large cup settings better earl grey tea speed convenience compensates recommended cfh
# Original summary: good earl grey tea recommended
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tasting
#
#
# Review: stuff really hard find stores holiday season thrilled find amazon decent price making raw vegan chocolate avocado pudding color appetizing use regular cocoa need special dark avoid turning greenish brown case wondering recipe tablespoons hershey special dark cocoa tablespoons honey agave full fat coconut milk cream tsp vanilla ripe blender blend blend blend totally smooth spoon small dishes chill believe awesome tastes taste avocado
# Original summary: yes it is dark
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: not as good as expected
#
#
# Review: dog loves lbs regular size perfect seems help teeth
# Original summary: great
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my dog loves these
#
#
# Review: dogs love treats chews keep dogs teeth cleaned love know get home work every night get treat excited highly recommend plus much cheaper amazon com local petsmart petco
# Original summary: my dogs love these
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my dog loves these
#
#
# Review: suffering post nasal drip congestion many years tea made big difference couple days drink times per day feel much better breathe easier little post nasal drip throughout day
# Original summary: this tea works feel so much better
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great product
#
#
# Review: huge fan canned coffee drinks always looking easy coffee drink tasted okay weird aftertaste cannot quite describe size adequate definitely purchasing future like convenient tasting coffee
# Original summary: illy issimo coffee drink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tea
#
#
# Review: using brand ginseng royal jelly several months need energy boost morning smoothies pleasant flavor compared pure ginseng love way perks without caffeine price amazon lower anywhere found get quickly
# Original summary: the real power booster
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted summary: great tasting
#
#
# Review: vet recommended rabbit based food cat difficult find seems allergic chicken regular cat food menu unfortunately crazy food spoiled brat cat
# Original summary: specialty cat food
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my cats love these
#
#
# Review: cumin expensive spice small bottles supermarkets love cumin season various recipes buy two share
# Original summary: great bargain
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: received free sample hour energy smiley really liked using product tasted good leave jittery even husband works night shift started using hour energy regularly since safe packed full vitamins comes variety flavors want mention though contain niacin flush anyone sensitive purchase
# Original summary: yummy and energizing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great for the price
#
#
# Review: kellogg special granola bars chocolate peanut butter flavored make nice low guilt snack flavors fairly subtle little sweet tasting granola makes filling bar calories net carbs protein recommended cfh
# Original summary: good snack
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great tasting
#
#
# Review: recently tried cooking chinese home served kung pao chicken made sauce rave reviews fights leftovers
# Original summary: gourmet chinese dinner
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: might work well training way tiny treat give whole handful disappointed
# Original summary: too tiny
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my dog loves these
#
#
# Review: gluten free want crackers one also delicious second order
# Original summary: cracker of cracker
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: love using fresh ginger lemon cook saw ginger lemon drink try flavor good leave slight taste enough deter trying complaint received sample pack gold kili drink directions much water use tend like foods drinks flavorful opted regular coffee mug found strong ended pouring largest one thought provided nice change pace basic varieties teas coffee warm drinks market today
# Original summary: powerful flavor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: not as good as expected
#
#
# Review: received product review unfortunately sample enough one serving possible give product valid review small sample size provided impressed maybe flavor needs chance savored
# Original summary: not enough product in sample for review
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: cats years old gotten older tummies seem become delicate research decided try natural balance difference made amazing coats shiny lush would even say shed less cat skin condition like dandruff longer suffers took bit time get used food course mix old food week happen run give cheaper food turn noses fortunately amazon prime order one day food next
# Original summary: changed my cats for the better
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my cats love this
#
#
# Review: using satin ice many years lately quality diminished cracks appear almost immediately little start pray unacceptable researching alternatives business
# Original summary: quality cracks
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: tea hard find bought boxes open packet bag smells exactly like fresh peaches taste masked flavors cinnamon makes wonderful iced tea
# Original summary: stash peach tea
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tea
#
#
# Review: mars american company found actually bought germany fans almond joy mounds past better really know better perhaps fresh coconut taste better chocolate either way awesome like almond joy mounds chocolate coconut love really hope become popular sell stores pros like mounds steroids milk chocolate dark come dark chocolate really really really good cons sweet side cannot eat lot without getting tummy ache could good portion control perhaps could pro haha healthy snack buy right tip try putting fridge consume mmmmmm
# Original summary: my mouth loves these
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: not as good as expected
#
#
# Review: last week hungry girl good morning america claimed best soup ever ever ever big fan campbell tomato soup enjoyed various progresso tomato soups try fantastic see one reviews mentioned using pasta sauce definitely see one thing surprised low sodium version soup couple negative reviews sweet amount sugar wonder lower salt content makes sweetness stand
# Original summary: best tomato soup have had
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great product
#
#
# Review: recipe favorite bought boxes flavor last years deer hunting season everyone tried impressed flavor add liquid smoke salt additional cayenne pepper batches make enough deer jerky fill gallon bags every season far best tried date
# Original summary: great taste great price
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted summary: great product
#
#
# Review: sure much say gum favorite gum decided buy bulk big container looks pretty stylish prone bust open gets knock table desk deduct one star case likely keep stocks refreshed another order road
# Original summary: gum with nice bite
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: used clear scalp hair beauty volumizing root boost nourishing shampoo conditioner week enjoying light bouncy hair ton fine medium blonde hair lower back shampoo conditioner combo really works shampoo hair every day buying review samples run gives good results great price
# Original summary: very light and bouncy hair
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: ordered looking one show said product lot vitamins minerals compared brands drink lot coconut water exercising tasted first time taste zico weird tastes like plastic mixed coconut water actually plastic coconut water different taste sweet tastes bland trying bottles found older brand sweet husband likes zico better guess going alternate subscription zico brand
# Original summary: very different taste
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted summary: great tasting
#
#
# Review: unable find supermarkets since april finally decided order service fast product looking never tried makes mongolian beef better chinese restaurant
# Original summary: best ever
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: delicious great breaded pork chops chicken lived okinawa cannot buy locally case every year give christmas presents daughter husband children like one favorites
# Original summary: tonkatsu sauce
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: used candy bar every one loved taste great thank hope get colours soon
# Original summary: love it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great
#
#
# Review: takes care bob redmill good lot higher carbs atkins tastes much like soy cooked products taste bland empty far healthy would necessarily equate carbquick health food low carb diet use moderation perfect meant low carb substitute foods eating ton anyway every recipe made box comes great drop biscuits add heavy cream subtract amount water great light breading chicken parm fish course pancakes waffles great highly recommend product keep using long make like others said ridiculously overpriced amazon get netrition instead
# Original summary: delicious low carb alternative
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great for the price
#
#
# Review: second favorite bigalow teas tried great smell flavor usually honey allowed cool luke warm mixed whisky found awesome fat free sugar free mixer well
# Original summary: delicious
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tasting
#
#
# Review: ignored reviews figured would bad ever wrong disappointed horrible selection even one iced tea one half regular tea green tea joke favor move wish amazon ashamed product need seriously consider process works
# Original summary: horrible
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: amazed well little cups taste kcups taste well hot chocolate taste great ready one minute
# Original summary:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tasting
#
#
# Review: far best tasting junk food snack ever put mouth heard lot friends tried fortunately could lay hands small packet commercial snack comes even close great taste pirate booty indeed felt like got hold great booty tasted get sorry
# Original summary: best tasting snack ever
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great tasting
#
#
# Review: tried several brands probably favorite terms crispiness salt content would hesitate call spicy price outrageous packets small difficult separate unless want cut apart scissors still tasty
# Original summary: excellent flavor but pricey and not very spicy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: longterm health longevity said animal byproduct best harmful said dog food given mainly treat reward time time every meal probably buying much bit pricey dogs absolutely love stuff eat stuff like eat chocolate bars allow course much dogs eat complete pigs beg beg table try limit amount table food get couple times week sometimes though give wife sad puppy dog eyes give funny least sirloin least favorite steak eat people love dogs certainly afford great way give dogs nice treat
# Original summary: really don know what all the is about
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: my dog loves it
#
#
# Review: husband drink nothing double bergamot earl grey stash used straight stash much faster still good price probably set autoship order soon figure fast boxes like earl grey really need try tea also green tea version
# Original summary: the best earl grey
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: took time finally got cats savor newman organics adult cat dry formula red tabby male penchant upchucking food put stop pellets small hard seem love crunching also mix newman organics advanced cat dry formula small amounts dry cat food treats premium cat food love packaging effective zip lock graphics highly recommend newman organics
# Original summary: my cats savor newman own organics
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my dog loves it
#
#
# Review: great low fat high protein treat make dog gas due high protein may hard digest used special treat given randomly regularly
# Original summary: makes doggie have gas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: my dog loves these
#
#
# Review: quite excited try product bought packs opened one tested half tablet result wife tried half ditto next day tried full tablet letting completely dissolve entire tongue found tablets pretty tasty wife found chalky enjoy anyway effect lemons chili sauce etc daughter also discernible change taste foods happily company going refund three packages would preferred would worked looking forward bringing upcoming party
# Original summary: no effect on anyone in our family
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: tried ordering amazon first time worried getting cans little top family three consumed within two weeks great flavor great snack order
# Original summary: great taste
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: dog trainer recommended product treat treats dog shape dog food balls fit inside kong toy put freezer certain occasions gets toy stuffed yummy healthy treat absolutely loves special reward
# Original summary: gold medal treat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: my dog loves these
#
#
# Review: thought normally snack fruit bars like took bit get accustomed sticky oily fruit bar coming last couple bars key lime pie ventured get coconut pie oddly almost tasted except slightly stronger coconut taste still core dates nuts etc really jumped last key lime pie noticed fuzzy edge bar box stated expired either hoping single bad bar box however help search term comments someone whole box bad see coconut pie fares mental image stuck alternative may seek another late afternoon snack
# Original summary: taste but surprise on last pack of white fuzzy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tasting
#
#
# Review: first cal sweetener tolerate wish affordable available larger quanities
# Original summary: tolerate no cal sweetener you should try this one
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: purchased product late last week husband buying local mom pop store week pleased results placed order told thought would tuesday wednesday latest tuesday morning ups truck rolled driveway order could pleased speed delivery fast well packaged properly sized box minimal packing materials also looked products site ordering soon prices good compared health food store generally get products thank great service appreciated annette maine
# Original summary: all star success
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: first time ordered find worth price order wanted cannot beat free shipping
# Original summary: priced less then at stores
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: raw pies mix chocolate puddings moisturize hair skin soothe rough elbows etc melts really fast pan need high heat fry eggs coconut taste subtle ethnic dish requires sauteeing saucing benefit fresh coconut flavor useful cooked meats well hate smell taste coconut obviously brand nutiva organic virgin smells good old jar never finished nearly two years later sitting right stove still smells fresh like cuban coconut candy mom used make yes solid fresh white fragrant two years later stable product recommended
# Original summary: amazingly fresh coconut smell and multiple uses plus organic
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great for the price
#
#
# Review: package product plastic containers boiling hot organic make sense
# Original summary: organic may be safe no
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: agree reviewers peanut butter taste prevails chocolatey one problem love love love peanut butter taste even though love chocolate okay peanut butter stronger one main issue particularly tasty filling bar overall think phrase okay characterizes one perfectly horrible first choice buying choosing amongst bars different varieties also hungry less hour course expect fill whole day even half day hoping couple hours
# Original summary: it was just okay treat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tasting
#
#
# Review: keurig two years drink one cup every morning every time run type coffee buy box something different first box actually thrown away would recommend coffee keurig
# Original summary: dissapointed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: making food month daugher far made enough bulk fill food saver eat amounts eating would even half little serving size container cna wait use bit older eating
# Original summary: yummy in pink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great product
#
#
# Review: flavor fear super energy drink good gave lot energy great afternoon pick got housework done record time
# Original summary: tasty and zippy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tasting
#
#
# Review: tried halo products previously happy thought would give one try first bought local pet supply store ran paragon toothbrush chews one day turns pom mix loves spot chews smell great well issue lot chew small dog although labeled small medium pets hard break husband slicing thirds knife would give third chew day one cute thing look top actually shaped like hearts
# Original summary: our dog loves these minty chews
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: my dog loves it
#
#
# Review: great bars taste exactly like south beach diet cinnamon rasin breakfast bars eat one every morning coffee full protein fiber tastes great
# Original summary: cinnamon bars are awesome
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great tasting
#
#
# Review: far one best gluten free pastas one best pastas period meaning would pick glutenous pastas great taste continue buy pasta long around
# Original summary: one of the best
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: product exactly expected previously bought retail stores
# Original summary: canned
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great product
#
#
# Review: stuff yummy put rice almost every morning breakfast adds flavor texture sweet
# Original summary: aji nori furikake
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great tasting
#
#
# Review: found taste bit strong side definitely seafood flavored could distinguish seafood still passable though portions large enough
# Original summary: fair to good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted summary: great tasting
#
#
# Review: sure jell favorite jell jam canning easy instructions easy use
# Original summary: great for jams
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: cheese sauce dehydrated vegetable pieces seasonings say taste okay anything special velveeta american cheese american cheese cheddar poor substitute hand velveeta cheese sauce beats heck powdered cheese sauce mix mix water milk like get helper meals respect velveeta box meal wins hands would suggest use meal chicken pork well flavor bold enough stand beef feel limited chicken says box helper person like meal helper person feel like moved notch frankly could better buying frozen broccoli dried pasta jar cheese sauce
# Original summary: it okay but not all that special
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: great for the price
#
#
# Review: bag bag misleading product thought buying bags happy gone local dollars per bag
# Original summary: not oz this is oz bag
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: gives good shine recommend daily use smell strong like fact need tiny drop use ends hair treatment shampooing
# Original summary: it arrived on time and in good condition
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: drink really good flavor sweet strong really good refreshing beverage would buy
# Original summary: great
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: love tea glad amazon carries hard find stores one place know carries way expensive buying online great herbal tea strongly cinnamon naturally sweet need add sweetner also find tea bags long way use large saucepan full water find taste somewhat addicting find regular tea boring drinking
# Original summary: perfect tea
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: good tea
#
#
# Review: bars natural taste good weight watchers diet bars worth points side arrive mail melted wish seller would pack ice arrive tact might dumb idea
# Original summary: oskri coconut bars
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great for gluten free
#
#
# Review: pamela products always good one exception complaint expensive products depend pamela products use recipes web site
# Original summary: great as usual
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: saw price amazon jumped great deal compared others found internet bought box jelly belly tangerine jelly beans wedding favors great steal
# Original summary: satisfied
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: revised previous review matter could get rid lumpy stuff unpleasant get mouth recommended
# Original summary: could not get rid of the lumps
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: cat absolutely loves food likes weruva canned foods one favorites
# Original summary: cat loves this food
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: my cats love these
#
#
# Review: coffee smooth enjoy much continue purchase good pecan sandie cookie
# Original summary: kona blend
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great tea
#
#
# Review: item like items pictured stated food items outdated stale included items like halloween pocky stale yogurt cakes received much better items japan overall disappointing
# Original summary: disappointing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted summary: great product
#
#
# Review: gusto aside passing taste test treats really good dog wheat free treats made barley lamb natural ingredients treat rectangular cookie scored snapped two treats lily would like point reason waste energy dividing treat trouble eating whole thing reminded smaller dogs might enjoy compact treat reluctantly agreed scoring good idea small dogs treats smell good humans based ingredient list healthy addition dog diet price pack six bags bad compared premium dog treats newman treats package making bit expensive bad considering quality
# Original summary: and incredibly tasty according to lily the golden retriever
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted summary: my dog loves it
#
#
# Review: thought going dried fruit turns dried full sugar needed taste though
# Original summary: sugar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: great product
#
#
# Review: since husband diagnosed celiac become quite gluten free baker collected ingredients make great cakes scratch however baking bread totally different thing anyway entire line pamela gluten free wheat free flours fantastic love making pizza flour gives fluffier slightly sweet crust trick pizza dough bake til slightly brown put toppings get crispy crust also fun suggestion adding herbs flour mixing also sprinkle herbs little olive oil first bake use flour weekly focaccia eggs
# Original summary: fast and easy delicious bread
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great for gluten free
#
#
# Review: delicious cup coffee anytime without waste making full pot searching sites found amazon com best price
# Original summary: great cup of coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tea
#
#
# Review: need something everyday use may awesome tea world noticed reviewed confused rave reviews great tea nostalgic tastes like tea remember lipton took market share also tea consistently good leaves small steep long get bitter taste combat drinking milk raw sugar sri lanka price much better tea anything found local supermarket
# Original summary: my favorite new house tea
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: good for the price
#
#
# Review: think read understand exp date read expiration date stated plasmon per numero lotto che prima successive successive uso per package number represent year production days need simple calculation around september reference plasmon read package made september know months guaranteed freshness good luck
# Original summary: think yo should read and understand exp date
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great product
#
#
# Review: tried look whole grain barley local supermarkets failed found amazon com pleased purchase chewy delicious loaded nutrients made barley water used cooked barley salad highly recommend product bob red mill whole hull less barley
# Original summary: hull less barley
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great for gluten free
#
#
# Review: special cereal vanilla flavor family like like great buy kids
# Original summary: special cereal vanilla
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted summary: great tasting
#
#
# Review: pancakes delicious fluffy ones normally make next time use going whip egg whites see helps
# Original summary: tasty pancakes but little flat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great product
#
#
# Review: schnauzer mix puppy easily bored extremely destructive likes puzzles looked perfect takes bit work get food knew would occupy screw lid bottom jug virtually seamless tight ran fingers seam giving could barely feel gave went work came home lunch completely destroyed located seam somehow wedged teeth worked way around circumference pried lid loose chewed lip jug way around lid cannot put back lying calmly food gone clearly long since finished hours since given
# Original summary: bullet proof maybe for rubber
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: my cats love this
#
#
# Review: dental work done three dogs vet suggested chews biggest problem dogs fight hah dental work yet
# Original summary: but didnt want to pay double what paid here
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: my dog loves these
#
#
# Review: difficulty finding blend local stores trying many different flavors past months find enjoyable blend yet followed closely kona blend thanks amazon carrying blend affordable price
# Original summary: extremely enjoyable
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted summary: great tasting
#
#
# Review: picked one use laptop running windows home premium computer saw item said needed troubleshooting nothing worked researching online found many people run problem apparently compatible windows supposedly corrected newer runs way tell one purchasing newer tried contacting blue twice hoping get update check exchanging never got response attempts finally return
# Original summary: windows users pay attention
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Predicted summary: great product
#
#
# Review: nutiva company based sebastopol california hemp seed excellent stir fries salads ounce pouches last awhile used hemp seed substitute sesame seed stir fries simply season expanded edition well mayan wonder bars pasta primavera vegan fusion world cuisine extraordinary recipes timeless wisdom celebrated blossoming lotus restaurants versatile subtle nutty flavor add extra protein nutritious delicious
# Original summary: going nuts
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted summary: great product
#
#
# Review: love soyrizo hannaford brothers longer carrying called whole foods store carry either price soyrizo shipping charges amazon prohibitive disappointed access product anymore
# Original summary: where has it gone in the supermarket
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: slightly different version different brand son started using around six months really enjoys get messy eats something sticky juicy like banana watermelon whatever anyway also trouble cleaning tried scrubbing nail vegetable brush works pretty well takes time much would take run food food mill blender cut clean chair floor dog well get picture
# Original summary: great for eating whole foods clean with veggie brush
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: my dog loves it
#
#
# Review: love coffee little pops mouth nice bitter punch palate kicks gut way like coffee
# Original summary: packs punch
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tea
#
#
# Review: ordered lemonheads amazon could find locally mom constantly used said kept dry mouth bay fast service mom tickled
# Original summary: mom loved them
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: splash vita coco water easier drink water staying hydrated life leg cramps problem far one box always busted shipping need get fixed
# Original summary: love the product need better shipping
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great tasting
#
#
# Review: wheat free bread mix great whole family enjoys taste add ground flax also done pizza mix also good good wheat free gluten free families great product
# Original summary: wonderful product
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tasting
#
#
# Review: cats love order chicken soup cat lover soul dry cat food senior cat chicken flavor pound bag
# Original summary: lover soul dry cat food for senior cat chicken
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: my cats love these
#
#
# Review: ordered box potato chips months ago love popchips tastes great one thing problem little salty anyone less tolerance salt careful
# Original summary: great chip little salty for me
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tasting
#
#
# Review: enjoyed taste close orange soda initially another sweet taste end sip unlike orange soda healthier added sugars even though product tastes like orange soda think would well breakfast may even become preferred traditional orange juice children businesses worry short shelf life downside price little high small buying
# Original summary: pretty good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great tasting
#
#
# Review: mix vanilla really great versatile stuff starters love protein source whey soy also use real ingredients locally made boulder mix great meal replacement meal supplement snack recovery drink since require refridgeration keep ski bag ski drink also triathlons find mix great pre race meal upset stomach later racing finally mix perfect recovery drink long workout
# Original summary: erin
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ...
# Original summary: where has this stuff been all my life
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted summary: great tasting
#
#
# Review: roommate college used buy nong shim shin cups loved lot want cook styrofoam every day noodles soooo good beware contain msg think everything moderation really love taste noodles sometimes buy beef chicken stock cook noodles instead soup flavor pack included
# Original summary: sooo good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: great product
#
#
# Review: bought multiple times let many others try everyone loves simply cannot stop eating
# Original summary: excellent
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: son loves gumball machine purchased gumball refills always ton friends quick gumballs seem little stale bite crumble adults may love kids purchase runs
# Original summary: gumball refill
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: good brand shichimi contain hemp seed contrary description says see labeling lists asa among ingredients
# Original summary: according to the labeling it does have hemp seed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: could believe absolutely delicious pasta perfect texture tastes fantastic know reviewer pasta turned gummy mine problems look substitute regular pasta actually like better sides stick together like regular pasta either bottom pan einkorn flour dissolves quickly unlike wheat flour products made less sticky try promise like
# Original summary: better than pasta made from regular wheat flour
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great for gluten free
#
#
# Review: someone sensitive stomach always challenge find protein drinks irritate stomach also taste great good nutritional profile mix brand found meets requirements ordered vanilla shake soon saw available amazon really enjoy natural vanilla flavour taste artificial like vanilla flavoured protein drinks tastes like delicious vanilla milkshake without heaviness real milkshake consistency shake little bit thinner regular mix protein drinks used definitely watery really like breakfast morning usually feel like downing whole one regular mix protein drinks slightly thicker consistency prefer afternoon
# Original summary: another great protein drink from mix
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: not as good as expected
#
#
# Review: without risk chance clumpy matcha one wants wisked two ounces warmed water electric frother matcha fully dissolved filled bowl rest warmed water ounces worth found caramel missing element maybe sweetness something usually associate caramel red leaf tea add sugar matchas found benefited added sweetener also think might prefer caramel matcha prepared sweeter latte either hot cold look forward playing around caramel matcha mixing flavored matchas company caramel cheesecake caramel green apple caramel espresso caramel vanilla name bet baking going amazing
# Original summary: fantastic flavored matcha it is sugar free
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great tasting
#
#
# Review: product made romania amazon left information word warning first gluten free product happened boiled pot paste suitable making paper mache suitable eating tried using bigger pots water still luck also cooking time way matter long cook pasta dissolves pasta never reaches stage done one dozen pastas used one problem also first corn pasta used
# Original summary: information bad product
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted summary: great product
#
#
# Review: wanted say picked first single serving primal spirit texas bbq meatless vegan jerky today local home searching gluten free products going say carnivore absoulte jerky fanatic made beef deer rabbit fish bison buffalo even turkey jerky honestly say fantastic nice stringy texture like actual meat flavored nicely little left wanting glad bought one think could eaten several also love fact calories fat still protein
# Original summary: omg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: good drink like ginger think could bit lemony made big cup beverage ginger bit bite drink exception sensitive spicy foods may cup tea dissolved easily hot water looking something different try beverage would good hot ice
# Original summary: instant ginger drink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: love this stuff
#
#
# Review: first time tried sea vegetables love right amount crunch taste good use salad take place croutons crackers bread easy use rinse throw salad tried way yet definely buy
# Original summary: great product
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: satisfying treat especially long aerobic workout good sinful treat enjoyed anytime whether watching one favorite episode reward finishing extra mile two treats knocked way one treats lunch time found tasted even better chilled one ate lunch lunch bag fridge bars good texture consistency either room temperature chilled quite filling especially water gave couple two acquaintances raved treat also one brought work left casually desk mysteriously disappeared perhaps grew legs walked interests minimizing workplace theft strongly suggest keep treats lock key
# Original summary: would buy it if could find it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great product
#
#
# Review: ordered charms blow pops received days best service price excellent
# Original summary: excellent service
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: read labels really start products may taste really good may full nasty things really want children eat term gluten free example important gluten intolerance kudos manufacturer making healthier product would liked given flavor better review taste black cherry flavor lot better taste still looking seemingly healthier beverage pack child lunch could worth try think flavored carbonated water gave stars unhealthy bad something like taste would sooner put product child lunch soda daddy used put soda car battery terminals dissolve acid
# Original summary: orange tangerine carbonated fruit drink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: not as good as expected
#
#
# Review: bean smelled fresh moist plump impressed quality beans shipped cannot wait use baked goods
# Original summary: very very moist beans
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: bones sure would getting look like dog chew bones big white knotted pieces rawhide come flimsy bag popped open since also shipping box really matter thing matters get rawhide dollar dogs chew stuff pretty fast first dogs excited guess flavored like smaller brown yellow bones set floor walked away took minutes picked began chewing away hand hesitate happily run corners chew price wise works ounce long lasting bones compare even cheapy bones cent store half price pretty satisfied dogs busy
# Original summary: definitely good deal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: my dog loves it
#
#
# Review: following instructions using low fat milk healthier butter alright great esp considering price doctored bit added madagascar vanilla flaxseed psyllium usually pancakes tasted bit better overall rating stars stuck eat purchase probably try next time full fat milk butter recommended see makes difference probably highly recommend organic pancake mix also amazon tastes much better fluffier like whole grain pancakes also love kodiak buttermilk mix also amazon healthy hearty good even kids love best add water makes portable even took hawaii
# Original summary: nothing special for what you pay
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: not as good as expected
#
#
# Review: slowed dog seconds think actually inhale food since channel
# Original summary: its ok
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: my dog loves these
#
#
# Review: hit office good cream sugar like drinking candy bar brownie obviously anything beats office coffee stuff pretty good went good ways individual bags make easy fix well
# Original summary: excellent flavor individually bagged for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great tasting
#
#
# Review: unless read fine print know turkey chicken formula actually contains turkey chicken whitefish upon opening immediately get hint something fishy perhaps others reported food contaminated single dog serious case fish breath next day occasionally passing fishy smelling gas get wrong dog loved food read enough reviews satisfied good quality doubt would love gobble think family appreciate fishy smell
# Original summary: turkey and chicken formula smells like fish
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Predicted summary: my dog loves it
#
#
# Review: ordered donut shop coffee really enjoyed wanted taste flavors offered receiving order sampler pack disappointed half order decaf coffee got cups flavored coffee main reason ordered love coffee disappointed called sampler pack lack variety pack
# Original summary: disappointed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: great tasting
#
#
# Review: try piece chocolate fall love probably one best chocolates produced switzerland europe whole think rather cheap quality get
# Original summary: absolutely perfect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted summary: great tasting
#
#
# Review: mother put bottle salad cream luggage went home belize year half ago found unpacking quickly finished last week found publix atlanta two bottles left bought buy every time see stock love stuff
# Original summary: found it in the grocery store
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted summary: great product
#
#
# Review: container medium size like size convient purchase item could find small container local grocery store love cook beef flavored bouillon great purchase
# Original summary: beef flavored bouillon
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted summary: great product
#
#
# Review: anything contains fake crap like chocolatey junk get vote bad cannot call chocolate legally call chocolatey shame
# Original summary: chocolatey
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great
#
#
# Review: son ocd thing food texture always hated nuts expect like cookies even chocolate shocked enjoyed much comes something like cookies could care less healthy might want treat everyone family enjoy definitely
# Original summary: the picky eater loved these
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted summary: great for the price
#
#
# Review: mystery chocolate filled breakfast cereals well thankfully back nature chocolate delights granola fits bill whatever means cereal exact balance granola chocolate sugar always dreamed plus find yucky corn syrup ingredients top notch chocolate chunks outstanding perfect shape size melt mouth bowl first chocolate cereals seen turn milk brown blown away said cereal balanced sweet breakfast likely appeal refined adult chocolate lover well kid two gripes granola little loose little pieces eat easily straight bag moderate high sog factor left milk
# Original summary: chocolate for breakfast
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted summary: not as good as expected
#
#
# Review: using ahmad tea long time best tea ever tasted used purchase different stores san francisco bay area paid box containing tea bags got amazon less half order quick arrive home recommend tea value exceptional service provided amazon
# Original summary: best taste tea ever
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
